# %%
# !g++ phuongtrinhtrungphuong.cpp -o phuongtrinhtrungphuong

# %%
# %%writefile test1.inp
# 1 -5 6
# Out:
# Writing test1.inp

# %%
# !./phuongtrinhtrungphuong <test1.inp
# Out:
#  The equation has 4 real solution(s): 1.73205 -1.73205 1.41421 -1.41421
