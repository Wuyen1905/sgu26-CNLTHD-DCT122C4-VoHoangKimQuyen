# %%
# !g++ phuongtrinhtrungphuong.cpp -o phuongtrinhtrungphuong

# %%
# !./phuongtrinhtrungphuong
# Out:
# Test 1 (Phuong trinh co 4 nghiem thuc): PASS
# Test 2 (Phuong trinh co 4 nghiem (y^2-1=0)): FAIL (expected 4 solutions)
# Test 3 (FAIL: chi khai bao 2 nghiem nhung thuc te co 4): PASS
# Test 4 (Phuong trinh bac 2 -> co 2 nghiem hop le): PASS
# Test 5 (FAIL: mong doi nghiem khac thuc te): FAIL (expected 2 solutions)
# Test 6 (FAIL: thuc te vo nghiem): FAIL (expected 2 solutions)
#
# Summary: 3/6 tests passed.
